# %% [markdown]
# IRIS CLASSIFICATION(DECISION TREE (Vijay Ragavan G))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# Load the Iris dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/panda/iris.csv')

# Separate features (X) and target (y)
X = df.drop('species', axis=1)
y = df['species']

# Encode the target variable 'Species' into numerical format
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Assuming 'Id' column might not be present or is named differently in the loaded dataset
# Check if 'Id' column exists before dropping
if 'id' in X.columns:
    X = X.drop('id', axis=1)
elif 'Id' in X.columns:
    X = X.drop('Id', axis=1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

print("Data prepared and split into training and testing sets.")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# Data prepared and split into training and testing sets.
# X_train shape: (105, 4), y_train shape: (105,)
# X_test shape: (45, 4), y_test shape: (45,)

# %%
dtree = DecisionTreeClassifier(random_state=42)
dtree.fit(X_train, y_train)

print("Decision Tree Classifier trained successfully.")
# Out:
# Decision Tree Classifier trained successfully.

# %%
y_pred = dtree.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy on the test set: {accuracy:.2f}")
# Out:
# Model Accuracy on the test set: 1.00

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(dtree, feature_names=X.columns, class_names=le.classes_,
          filled=True, rounded=True, fontsize=10)
plt.title("Decision Tree for Iris Classification")
plt.show()
