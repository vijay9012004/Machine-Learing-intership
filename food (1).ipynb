# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression, LinearRegression

# %%
dia=pd.read_csv("/content/global_food_wastage_dataset2.csv")
dia.head()
# Out:
#      Country  Year  Total Waste (Tons)  Avg Waste per Capita (Kg)
# 0  Australia  2019            19268.63                      72.69
# 1  Indonesia  2019             3916.97                     192.52
# 2    Germany  2022             9700.16                     166.94
# 3     France  2023            46299.69                     120.19
# 4     France  2023            33096.57                     104.74

# %%
dia.isnull().sum()
# Out:
# Country                      0
# Year                         0
# Total Waste (Tons)           0
# Avg Waste per Capita (Kg)    0
# dtype: int64

# %%
inp=dia[['Country','Year','Total Waste (Tons)']]
out=dia['Avg Waste per Capita (Kg)']

# %%
inp_encoded = pd.get_dummies(inp, columns=['Country'], drop_first=True)
Log.fit(inp_encoded,out)
# Out:
# LinearRegression()

# %%
country_input = input("Enter the country (e.g., Australia, France): ")
year_input = int(input("Enter the Year: "))
total_waste_tons_input = float(input("Enter the Total Waste (Tons): "))


pred = Log.predict(prediction_df)
print(f"Predicted Avg Waste per Capita (Kg): {pred[0]:.2f}")
# Out:
# Enter the country (e.g., Australia, France): Austrlia
# Enter the Year: 2019
# Enter the Total Waste (Tons): 10
# Predicted Avg Waste per Capita (Kg): 105.76
