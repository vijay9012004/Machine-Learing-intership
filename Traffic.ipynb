# %% [markdown]
# Traffic(LinearRegression(Vijay Ragavan G))

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
saldf=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/panda/traafic.csv')

# %%
saldf.head()
# Out:
#    Junction  Vehicles  traffic
# 0         1        15        0
# 1         1        13        0
# 2         1        10        0
# 3         1         7        0
# 4         1         9        0

# %%
saldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Junction  1199 non-null   int64
#  1   Vehicles  1199 non-null   int64
#  2   traffic   1199 non-null   int64
# dtypes: int64(3)
# memory usage: 28.2 KB

# %%
saldf.isnull().sum()
# Out:
# Junction    0
# Vehicles    0
# traffic     0
# dtype: int64

# %%
inp=saldf[['Vehicles']]
out=saldf['traffic']

# %%
LR=LinearRegression()

# %%
LR.fit(inp,out)
# Out:
# LinearRegression()

# %%
LR.predict([[25]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.53899341])
